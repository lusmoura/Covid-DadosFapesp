# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Lendo datasets

# %%
fleury = pd.read_csv('../Dados/Fleury/Grupo_Fleury_Dataset_Covid19_Resultados_Exames.csv', sep='|', encoding = "ISO-8859-1")
fleury = fleury[['ID_PACIENTE', 'DT_COLETA', 'DE_ORIGEM', 'DE_EXAME', 
                       'DE_ANALITO', 'DE_RESULTADO', 'CD_UNIDADE', 'DE_VALOR_REFERENCIA']].copy()

# %%
fleury['DE_VALOR_REFERENCIA'] = fleury['DE_VALOR_REFERENCIA'].replace(np.nan, 'NaN')
fleury['CD_UNIDADE'] = fleury['CD_UNIDADE'].replace(np.nan, 'NaN')

# %%
fleury.loc[fleury['DE_VALOR_REFERENCIA'].str.contains('\d+', regex=True), 'DE_RESULTADO'] = 'Number'

# %%
fleury.head()
# Out:
#                         ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 2  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 3  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 4  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
#
#                                             DE_EXAME  \
# 0  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 2                            HEMOGRAMA, sangue total
# 3                            HEMOGRAMA, sangue total
# 4                            HEMOGRAMA, sangue total
#
#                    DE_ANALITO            DE_RESULTADO CD_UNIDADE  \
# 0  Covid 19, Detecção por PCR           NÃO DETECTADO        NaN
# 1          Covid 19, Material  raspado de nasofaringe        NaN
# 2                 Hemoglobina                  Number       g/dL
# 3                         VCM                  Number         fL
# 4                  Leucócitos                  Number       /mm3
#
#   DE_VALOR_REFERENCIA
# 0       Não detectado
# 1                 NaN
# 2         13,5 a 17,5
# 3         81,0 a 95,0
# 4      3.500 a 10.500

# %% [markdown]
# ## Vários exames de COVID-19

# %%
different_covid_exams = fleury[(fleury['DE_EXAME'].str.contains('COV')) | (fleury['DE_EXAME'].str.contains('Corona')) | (fleury['DE_EXAME'].str.contains('CORONAV'))]['DE_EXAME'].unique()

# %%
for exam in different_covid_exams:
    print(exam)
# Out:
# NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR
# COVID19, ANTICORPOS IgG, soro
# COVID19, ANTICORPOS IgM, soro
# COVID19, ANTICORPOS IgA, soro
# SARS-COV-2, ANTICORPOS IgG, soro

# %%
different_covid_exams.size
# Out:
# 5

# %%
fleury['count'] = 1

fleury_cov = fleury[fleury['DE_EXAME'].isin(different_covid_exams)].copy()
fleury_cov.groupby(['DE_EXAME', 'DE_ANALITO', 'DE_RESULTADO', 'CD_UNIDADE', 'DE_VALOR_REFERENCIA']).agg({'count':'sum'})
# Out:
#                                                                                                                         count
# DE_EXAME                         DE_ANALITO                               DE_RESULTADO  CD_UNIDADE DE_VALOR_REFERENCIA
# COVID19, ANTICORPOS IgA, soro    Covid 19, Anticorpos IgA, Elisa          Indeterminado NaN        Não reagente           270
#                                                                           NÃO REAGENTE  NaN        Não reagente          2462
#                                                                           REAGENTE      NaN        Não reagente           755
#                                  Covid 19, Anticorpos IgA, Elisa - Índice 0,15          NaN        NaN                      1
#                                                                           0,16          NaN        NaN                      2
# ...                                                                                                                       ...
# SARS-COV-2, ANTICORPOS IgG, soro Covid 19, Anticorpos IgG, Elisa          Indeterminado NaN        Não reagente            17
#                                                                           NÃO REAGENTE  NaN        Não reagente           400
#                                                                           REAGENTE      NaN        Não reagente            64
#                                  Covid 19, Anticorpos IgG, Elisa - Índice Number        NaN        inferior a 0,80        273
#                                                                                                    inferior a 1,01        208
#
# [110 rows x 1 columns]

# %%
fleury_cov['DE_EXAME'].unique()
# Out:
# array(['NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR',
#        'COVID19, ANTICORPOS IgG, soro', 'COVID19, ANTICORPOS IgM, soro',
#        'COVID19, ANTICORPOS IgA, soro',
#        'SARS-COV-2, ANTICORPOS IgG, soro'], dtype=object)

# %%
fleury['DE_EXAME'].nunique()
# Out:
# 722

# %%
fleury
# Out:
#                               ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 2        7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 3        7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 4        7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# ...                                   ...         ...       ...
# 2496586  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496587  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496588  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496589  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496590  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
#
#                                                   DE_EXAME  \
# 0        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 2                                  HEMOGRAMA, sangue total
# 3                                  HEMOGRAMA, sangue total
# 4                                  HEMOGRAMA, sangue total
# ...                                                    ...
# 2496586    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496587    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496588    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496589                                    FERRITINA, soro
# 2496590                        25 HIDROXI-VITAMINA D, soro
#
#                                   DE_ANALITO            DE_RESULTADO  \
# 0                 Covid 19, Detecção por PCR           NÃO DETECTADO
# 1                         Covid 19, Material  raspado de nasofaringe
# 2                                Hemoglobina                    15,2
# 3                                        VCM                    89,2
# 4                                 Leucócitos                    5940
# ...                                      ...                     ...
# 2496586  FAN - Placa Cromossômica Metafásica            Não reagente
# 2496587                 FAN - Citoplasmático            Não reagente
# 2496588              FAN - Aparelho Mitótico            Não reagente
# 2496589                            Ferritina                      66
# 2496590              25 Hidroxi - vitamina D                      25
#
#         CD_UNIDADE DE_VALOR_REFERENCIA  dummy
# 0              NaN       Não detectado      1
# 1              NaN                 NaN      1
# 2             g/dL         13,5 a 17,5      1
# 3               fL         81,0 a 95,0      1
# 4             /mm3      3.500 a 10.500      1
# ...            ...                 ...    ...
# 2496586        NaN        Não reagente      1
# 2496587        NaN        Não reagente      1
# 2496588        NaN        Não reagente      1
# 2496589   microg/L            15 a 149      1
# 2496590      ng/mL                 NaN      1
#
# [2496591 rows x 9 columns]

# %% [markdown]
# ### Exemplos

# %%
cov_exams = fleury[(fleury['DE_EXAME'].str.contains('COV')) | (fleury['DE_EXAME'].str.contains('Corona')) | (fleury['DE_EXAME'].str.contains('CORONAV'))].drop_duplicates(subset=['DE_EXAME', 'DE_ANALITO', 'DE_RESULTADO'])

# %%
cov_exams['DE_RESULTADO'] = cov_exams['DE_RESULTADO'].str.replace(',', '.')
cov_exams['DE_RESULTADO'] = cov_exams['DE_RESULTADO'].apply(lambda x : check_float(x))

# %%
cov_exams
# Out:
#                               ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 75       7B10786D64F27D7732503D915A38DE6F  12/04/2020       LAB
# 76       7B10786D64F27D7732503D915A38DE6F  12/04/2020       LAB
# 77       7B10786D64F27D7732503D915A38DE6F  03/06/2020       LAB
# ...                                   ...         ...       ...
# 2481586  9C9AA041D47370FE49C5B1A4E2A61D27  15/06/2020       LAB
# 2483225  824ED070005D1AFC37C86AF38D20059A  15/06/2020       LAB
# 2485709  BE396400942EFF8F7E6BC1AD1542E8D7  15/06/2020       LAB
# 2494938  64AF300E5BD88A574D5214AC785245BD  11/05/2020       LAB
# 2495315  60A5A184B03A04F5BF33B040C516B61C  09/05/2020       LAB
#
#                                                   DE_EXAME  \
# 0        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 75                           COVID19, ANTICORPOS IgG, soro
# 76                           COVID19, ANTICORPOS IgM, soro
# 77                           COVID19, ANTICORPOS IgG, soro
# ...                                                    ...
# 2481586                      COVID19, ANTICORPOS IgG, soro
# 2483225                      COVID19, ANTICORPOS IgG, soro
# 2485709                      COVID19, ANTICORPOS IgG, soro
# 2494938                   SARS-COV-2, ANTICORPOS IgG, soro
# 2495315                   SARS-COV-2, ANTICORPOS IgG, soro
#
#                                             DE_ANALITO  \
# 0                           Covid 19, Detecção por PCR
# 1                                   Covid 19, Material
# 75       Covid 19, Anticorpos IgG, Quimiolumin.-Índice
# 76       Covid 19, Anticorpos IgM, Quimiolumin.-Índice
# 77       Covid 19, Anticorpos IgG, Quimiolumin.-Índice
# ...                                                ...
# 2481586  Covid 19, Anticorpos IgG, Quimiolumin.-Índice
# 2483225  Covid 19, Anticorpos IgG, Quimiolumin.-Índice
# 2485709  Covid 19, Anticorpos IgG, Quimiolumin.-Índice
# 2494938       Covid 19, Anticorpos IgG, Elisa - Índice
# 2495315       Covid 19, Anticorpos IgG, Elisa - Índice
#
#                    DE_RESULTADO CD_UNIDADE DE_VALOR_REFERENCIA
# 0                 NÃO DETECTADO        NaN       Não detectado
# 1        raspado de nasofaringe        NaN                 NaN
# 75               inferior a 1.0      UA/mL      inferior a 1,0
# 76               inferior a 1.0      UA/mL      inferior a 1,0
# 77                          0.1      UA/mL      inferior a 0,8
# ...                         ...        ...                 ...
# 2481586                    49.9      UA/mL      inferior a 0,8
# 2483225                    68.5      UA/mL      inferior a 0,8
# 2485709                    96.6      UA/mL      inferior a 0,8
# 2494938                    1.18        NaN     inferior a 0,80
# 2495315                    0.96        NaN     inferior a 0,80
#
# [2366 rows x 8 columns]

# %% [markdown]
# ## Pivot Table

# %%
pivot = full.pivot_table(index=['ID_PACIENTE', 'DT_COLETA'], columns='DE_ANALITO', values='DE_RESULTADO', aggfunc=np.max)
pivot
# Out:
# DE_ANALITO                                            183  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020           NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020           NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00  NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020           NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00  NaN
# ...                                                   ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020           NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00  NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00  NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020           NaN
#                                  23/04/2020           NaN
#
# DE_ANALITO                                           25 Hidroxi - vitamina D  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                              NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                              NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00                     NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                              NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00                     NaN
# ...                                                                      ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                              NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00                     NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00                     NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                              NaN
#                                  23/04/2020                              NaN
#
# DE_ANALITO                                           250H - Vitamina D Total  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                              NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                              NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00                     NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                              NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00                     NaN
# ...                                                                      ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                              NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00                     NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00                     NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                              NaN
#                                  23/04/2020                              NaN
#
# DE_ANALITO                                           25OH-Vitamina D Total  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                            NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                            NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00                   NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                            NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00                   NaN
# ...                                                                    ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                            NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00                   NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00                   NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                            NaN
#                                  23/04/2020                            NaN
#
# DE_ANALITO                                           ACTH ALT (TGP) AST (TGO)  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020           NaN       NaN       NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020           NaN       NaN       NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00  NaN       NaN       NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020           NaN       NaN       NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00  NaN       NaN       NaN
# ...                                                   ...       ...       ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020           NaN       NaN       NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00  NaN       NaN       NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00  NaN       NaN       NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020           NaN       NaN       NaN
#                                  23/04/2020           NaN       NaN       NaN
#
# DE_ANALITO                                           Adenovirus AgHBe AgHBs  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                 NaN   NaN   NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                 NaN   NaN   NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00        NaN   NaN   NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                 NaN   NaN   NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00        NaN   NaN   NaN
# ...                                                         ...   ...   ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                 NaN   NaN   NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00        NaN   NaN   NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00        NaN   NaN   NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                 NaN   NaN   NaN
#                                  23/04/2020                 NaN   NaN   NaN
#
# DE_ANALITO                                            ...  \
# ID_PACIENTE                      DT_COLETA            ...
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020           ...
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020           ...
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00  ...
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020           ...
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00  ...
# ...                                                   ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020           ...
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00  ...
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00  ...
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020           ...
#                                  23/04/2020           ...
#
# DE_ANALITO                                           pH (gasometria venosa)  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                             NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                             NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00                    NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                             NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00                    NaN
# ...                                                                     ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                             NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00                    NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00                    NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                             NaN
#                                  23/04/2020                             NaN
#
# DE_ANALITO                                           pH venoso pH, urina  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                NaN       NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                NaN       NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00       NaN       NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                NaN       NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00       NaN       NaN
# ...                                                        ...       ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                NaN       NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00       NaN       NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00       NaN       NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                NaN       NaN
#                                  23/04/2020                NaN       NaN
#
# DE_ANALITO                                           pO2 (gasometria venosa)  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                              NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                              NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00                     NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                              NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00                     NaN
# ...                                                                      ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                              NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00                     NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00                     NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                              NaN
#                                  23/04/2020                              NaN
#
# DE_ANALITO                                           pO2 venoso  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                 NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                 NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00        NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                 NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00        NaN
# ...                                                         ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                 NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00        NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00        NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                 NaN
#                                  23/04/2020                 NaN
#
# DE_ANALITO                                           Ácido ascorbico, plasma  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                              NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                              NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00                     NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                              NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00                     NaN
# ...                                                                      ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                              NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00                     NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00                     NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                              NaN
#                                  23/04/2020                              NaN
#
# DE_ANALITO                                           Ácido fólico  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                   NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                   NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00          NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                   NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00          NaN
# ...                                                           ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                   NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00          NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00          NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                   NaN
#                                  23/04/2020                   NaN
#
# DE_ANALITO                                           Ácido fólico - Eletroquimioluminescência  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                                               NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                                               NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00                                      NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                                               NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00                                      NaN
# ...                                                                                       ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                                               NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00                                      NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00                                      NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                                               NaN
#                                  23/04/2020                                               NaN
#
# DE_ANALITO                                           Ácido Úrico  \
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                  NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                  NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00         NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                  NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00         NaN
# ...                                                          ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                  NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00         NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00         NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                  NaN
#                                  23/04/2020                  NaN
#
# DE_ANALITO                                           Ácido Úrico, soro
# ID_PACIENTE                      DT_COLETA
# 024120776B6797AEBDFC12C0301B1A8F 06/04/2020                        NaN
# 027B6329D6AC1CD1B5DED1DCF87AD204 30/03/2020                        NaN
# 02B32473EF55DFB7EB96C68FA353A606 01/06/2020 00:00:00               NaN
# 058CA32F0DC54A4D0A52242409D85A79 17/04/2020                        NaN
# 06CBA5955242CD9F383B0E050FF5C21A 09/04/2020 00:00:00               NaN
# ...                                                                ...
# FC98B7A6A6D62C1EC4FB2A1EB1092C68 21/04/2020                        NaN
# FCCEB133D939375813ADDCE9931350B6 29/03/2020 00:00:00               NaN
# FDC916AB5986E6A1D05C6D674D55AAEA 05/04/2020 00:00:00               NaN
# FEA4AEEE2118866F62941EB73850FAD8 14/04/2020                        NaN
#                                  23/04/2020                        NaN
#
# [535 rows x 391 columns]

# %% [markdown]
# ### Exemplo

# %%
full[(full['ID_PACIENTE'] == 'FEA4AEEE2118866F62941EB73850FAD8') & (full['DT_COLETA'] == '23/04/2020')]
# Out:
#                           ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 680  FEA4AEEE2118866F62941EB73850FAD8  23/04/2020       LAB
# 681  FEA4AEEE2118866F62941EB73850FAD8  23/04/2020       LAB
# 682  FEA4AEEE2118866F62941EB73850FAD8  23/04/2020       LAB
# 683  FEA4AEEE2118866F62941EB73850FAD8  23/04/2020       LAB
#
#                           DE_EXAME  \
# 680  COVID19, ANTICORPOS IgG, soro
# 681  COVID19, ANTICORPOS IgG, soro
# 682  COVID19, ANTICORPOS IgM, soro
# 683  COVID19, ANTICORPOS IgM, soro
#
#                                         DE_ANALITO  DE_RESULTADO CD_UNIDADE  \
# 680  Covid 19, Anticorpos IgG, Quimiolumin.-Índice           0,6      UA/mL
# 681  Covid 19, Anticorpos IgG, Quimioluminescência  NÃO REAGENTE        NaN
# 682  Covid 19, Anticorpos IgM, Quimiolumin.-Índice           0,3      UA/mL
# 683  Covid 19, Anticorpos IgM, Quimioluminescência  NÃO REAGENTE        NaN
#
#     DE_VALOR_REFERENCIA
# 680      inferior a 0,9
# 681        Não reagente
# 682      inferior a 0,7
# 683        Não reagente

# %%
pivot.loc['FEA4AEEE2118866F62941EB73850FAD8'][['Covid 19, Anticorpos IgG, Quimiolumin.-Índice','Covid 19, Anticorpos IgG, Quimioluminescência','Covid 19, Anticorpos IgM, Quimiolumin.-Índice','Covid 19, Anticorpos IgM, Quimioluminescência']]
# Out:
# DE_ANALITO Covid 19, Anticorpos IgG, Quimiolumin.-Índice  \
# DT_COLETA
# 14/04/2020                                inferior a 1,0
# 23/04/2020                                           0,6
#
# DE_ANALITO Covid 19, Anticorpos IgG, Quimioluminescência  \
# DT_COLETA
# 14/04/2020                                           NaN
# 23/04/2020                                  NÃO REAGENTE
#
# DE_ANALITO Covid 19, Anticorpos IgM, Quimiolumin.-Índice  \
# DT_COLETA
# 14/04/2020                                inferior a 1,0
# 23/04/2020                                           0,3
#
# DE_ANALITO Covid 19, Anticorpos IgM, Quimioluminescência
# DT_COLETA
# 14/04/2020                                           NaN
# 23/04/2020                                  NÃO REAGENTE
