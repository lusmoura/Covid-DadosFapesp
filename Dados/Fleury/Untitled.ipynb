# %% [markdown]
# # Fleury Data

# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['Grupo_Fleury_Small_Dataset_Covid19_Pacientes.csv',
#  '.ipynb_checkpoints',
#  'Grupo_Fleury_Small_Dataset_Covid19_Resultados_Exames_1.csv',
#  'Untitled.ipynb',
#  'Grupo_Fleury_Dataset_Covid19_Dicionаrio de Dados.xlsx']

# %% [markdown]
# ## Reading files

# %%
exames = pd.read_csv('Grupo_Fleury_Small_Dataset_Covid19_Resultados_Exames_1.csv', sep='|', encoding = "ISO-8859-1"
)

# %%
pacientes = pd.read_csv('Grupo_Fleury_Small_Dataset_Covid19_Pacientes.csv', sep='|', encoding = "ISO-8859-1" )

# %% [markdown]
# ## Quick Analysis Exames

# %%
exames.head()
# Out:
#                         ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0  5B50C7FC316FAFEBF582DB9245E35DB5  02/11/2019       LAB
# 1  5B50C7FC316FAFEBF582DB9245E35DB5  02/11/2019       LAB
# 2  5B50C7FC316FAFEBF582DB9245E35DB5  02/11/2019       LAB
# 3  5B50C7FC316FAFEBF582DB9245E35DB5  02/11/2019       LAB
# 4  5B50C7FC316FAFEBF582DB9245E35DB5  02/11/2019       LAB
#
#                   DE_EXAME   DE_ANALITO DE_RESULTADO CD_UNIDADE  \
# 0  HEMOGRAMA, sangue total  Hemoglobina         11,9       g/dL
# 1  HEMOGRAMA, sangue total          VCM         81,5         fL
# 2  HEMOGRAMA, sangue total   Leucócitos         5970       /mm3
# 3  HEMOGRAMA, sangue total  Neutrófilos         2360       /mm3
# 4  HEMOGRAMA, sangue total  Eosinófilos          550       /mm3
#
#   DE_VALOR_REFERENCIA
# 0         12,0 a 15,5
# 1         82,0 a 98,0
# 2      3.500 a 10.500
# 3       1.700 a 7.000
# 4            50 a 500

# %%
exames.dtypes
# Out:
# ID_PACIENTE            object
# DT_COLETA              object
# DE_ORIGEM              object
# DE_EXAME               object
# DE_ANALITO             object
# DE_RESULTADO           object
# CD_UNIDADE             object
# DE_VALOR_REFERENCIA    object
# dtype: object

# %%
exames.describe()
# Out:
#                              ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# count                               2051        2051      2051
# unique                               100          73         1
# top     45DCA7A7639394D32453D6D615AF9156  08/02/2020       LAB
# freq                                 155         110      2051
#
#                        DE_EXAME                  DE_ANALITO   DE_RESULTADO  \
# count                      2051                        2051           2051
# unique                      135                         205            841
# top     HEMOGRAMA, sangue total  Covid 19, Detecção por PCR  NÃO DETECTADO
# freq                        814                         107             87
#
#        CD_UNIDADE DE_VALOR_REFERENCIA
# count        1467                1452
# unique         32                 160
# top             %       Não detectado
# freq          278                 107

# %% [markdown]
# ## Quick Analysis Pacientes

# %%
pacientes.head()
# Out:
#                         ID_PACIENTE IC_SEXO  AA_NASCIMENTO CD_PAIS CD_UF  \
# 0  5B50C7FC316FAFEBF582DB9245E35DB5       F           1982  Brasil    SP
# 1  027B6329D6AC1CD1B5DED1DCF87AD204       F           1982  Brasil    SP
# 2  ED9B795482AAF5BC59BD819076E922EC       F           1982  Brasil    SP
# 3  A9B12C356B595C43ADC11FC38477C8B1       M           1982  Brasil    SP
# 4  4AE0B3CE202C44CAE4782752C6ABDA17       F           1982  Brasil    SP
#
#   CD_MUNICIPIO      CD_DISTRITO
# 0    GUARULHOS   Jardim Barbosa
# 1    SAO PAULO  Vila Leopoldina
# 2    SAO PAULO     Vila Nhocune
# 3    SAO PAULO        Pinheiros
# 4         MAUA       Vila Dirce

# %%
pacientes.dtypes
# Out:
# ID_PACIENTE      object
# IC_SEXO          object
# AA_NASCIMENTO     int64
# CD_PAIS          object
# CD_UF            object
# CD_MUNICIPIO     object
# CD_DISTRITO      object
# dtype: object

# %%
pacientes.describe()
# Out:
#        AA_NASCIMENTO
# count          100.0
# mean          1982.0
# std              0.0
# min           1982.0
# 25%           1982.0
# 50%           1982.0
# 75%           1982.0
# max           1982.0

# %% [markdown]
# ## Merging files

# %%
merged = pacientes.merge(exames, on=['ID_PACIENTE'])

# %%
merged
# Out:
#                            ID_PACIENTE IC_SEXO  AA_NASCIMENTO CD_PAIS CD_UF  \
# 0     5B50C7FC316FAFEBF582DB9245E35DB5       F           1982  Brasil    SP
# 1     5B50C7FC316FAFEBF582DB9245E35DB5       F           1982  Brasil    SP
# 2     5B50C7FC316FAFEBF582DB9245E35DB5       F           1982  Brasil    SP
# 3     5B50C7FC316FAFEBF582DB9245E35DB5       F           1982  Brasil    SP
# 4     5B50C7FC316FAFEBF582DB9245E35DB5       F           1982  Brasil    SP
# ...                                ...     ...            ...     ...   ...
# 2046  DE185E011AE5D3A99B3E9DFCC7314840       M           1982  Brasil    SP
# 2047  DE185E011AE5D3A99B3E9DFCC7314840       M           1982  Brasil    SP
# 2048  DE185E011AE5D3A99B3E9DFCC7314840       M           1982  Brasil    SP
# 2049  70EC2CFEEEFC4001008937EE46F23F45       F           1982  Brasil    SP
# 2050  70EC2CFEEEFC4001008937EE46F23F45       F           1982  Brasil    SP
#
# ...

# %%
merged['CD_UF'].value_counts()
# Out:
# SP    2051
# Name: CD_UF, dtype: int64
