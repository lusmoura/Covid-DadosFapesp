# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import nltk
from seaborn import heatmap
import os
from fuzzywuzzy import fuzz
from itertools import combinations

# %%
# !ls '../Dados/Fleury/'
# Out:
#  fleury.zip
# 'Grupo_Fleury_Dataset_Covid19_Dicionário de Dados.xlsx'
#  Grupo_Fleury_Dataset_Covid19_Pacientes.csv
#  Grupo_Fleury_Dataset_Covid19_Resultados_Exames.csv

# %% [markdown]
# ## Lendo datasets

# %%
fleury = pd.read_csv('../Dados/Fleury/Grupo_Fleury_Dataset_Covid19_Resultados_Exames.csv', sep='|', encoding = "ISO-8859-1")
fleury_pacientes = pd.read_csv('../Dados/Fleury/Grupo_Fleury_Dataset_Covid19_Pacientes.csv', sep='|', encoding = "ISO-8859-1")
fleury = fleury[['ID_PACIENTE', 'DT_COLETA', 'DE_ORIGEM', 'DE_EXAME', 
                       'DE_ANALITO', 'DE_RESULTADO', 'CD_UNIDADE', 'DE_VALOR_REFERENCIA']].copy()

# %% [markdown]
# # EDA

# %%
fleury_pacientes['IC_SEXO'].value_counts() / fleury_pacientes['IC_SEXO'].value_counts().sum() * 100
# Out:
# F    56.650668
# M    43.349332
# Name: IC_SEXO, dtype: float64

# %%
fleury_pacientes.drop(columns=['AA_NASCIMENTO'], inplace=True)

# %% [markdown]
# ## Casos estranhos

# %% [markdown]
# ### Três valores de referência para o mesmo exame com mesmo analito

# %%
fleury[(fleury['DE_ANALITO'] == 'Covid 19, Anticorpos IgG, Quimiolumin.-Índice') &
       (fleury['DE_EXAME'] == 'COVID19, ANTICORPOS IgG, soro')]['DE_VALOR_REFERENCIA'].unique()
# Out:
# array(['inferior a 1,0', 'inferior a 0,8', 'inferior a 0,9', nan],
#       dtype=object)

# %% [markdown]
# ## Processando

# %%
fleury['DE_VALOR_REFERENCIA'] = fleury['DE_VALOR_REFERENCIA'].replace(np.nan, 'NaN')
fleury['CD_UNIDADE'] = fleury['CD_UNIDADE'].replace(np.nan, 'NaN')

# %%
fleury.loc[fleury['DE_VALOR_REFERENCIA'].str.contains('\d+', regex=True), 'DE_RESULTADO'] = 'Number'

# %%
fleury.head()
# Out:
#                         ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 2  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 3  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 4  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
#
#                                             DE_EXAME  \
# 0  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 2                            HEMOGRAMA, sangue total
# 3                            HEMOGRAMA, sangue total
# 4                            HEMOGRAMA, sangue total
#
#                    DE_ANALITO            DE_RESULTADO CD_UNIDADE  \
# 0  Covid 19, Detecção por PCR           NÃO DETECTADO        NaN
# 1          Covid 19, Material  raspado de nasofaringe        NaN
# 2                 Hemoglobina                  Number       g/dL
# 3                         VCM                  Number         fL
# 4                  Leucócitos                  Number       /mm3
#
#   DE_VALOR_REFERENCIA
# 0       Não detectado
# 1                 NaN
# 2         13,5 a 17,5
# 3         81,0 a 95,0
# 4      3.500 a 10.500

# %%
def check_float(string):
    try:
        number = float(string)
        return 'Number'
    except:
        return string

# %%
fleury['DE_RESULTADO'] = fleury['DE_RESULTADO'].str.replace(',', '.')
fleury['DE_RESULTADO'] = fleury['DE_RESULTADO'].apply(lambda x: check_float(x))

# %% [markdown]
# ## Vários exames de COVID-19

# %%
different_covid_exams = fleury[(fleury['DE_EXAME'].str.contains('COV')) | (fleury['DE_EXAME'].str.contains(
    'Corona')) | (fleury['DE_EXAME'].str.contains('CORONAV'))]['DE_EXAME'].unique()

# %%
for exam in different_covid_exams:
    print(exam)
# Out:
# NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR
# COVID19, ANTICORPOS IgG, soro
# COVID19, ANTICORPOS IgM, soro
# COVID19, ANTICORPOS IgA, soro
# SARS-COV-2, ANTICORPOS IgG, soro

# %%
different_covid_exams.size
# Out:
# 5

# %%
fleury['count'] = 1

# %%
fleury_cov = fleury[fleury['DE_EXAME'].isin(different_covid_exams)].copy()
fleury_cov = fleury_cov.groupby(
    ['DE_EXAME', 'DE_ANALITO', 'DE_RESULTADO', 'CD_UNIDADE', 'DE_VALOR_REFERENCIA']).agg({'count': 'sum'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-7db583a5094e> in <module>
#       1 fleury['count'] = 1
#       2
# ----> 3 fleury_cov = fleury[fleury['DE_EXAME'].isin(different_covid_exams)].copy()
#       4 fleury_cov = fleury_cov.groupby(
#       5     ['DE_EXAME', 'DE_ANALITO', 'DE_RESULTADO', 'CD_UNIDADE', 'DE_VALOR_REFERENCIA']).agg({'count': 'sum'})
#
# NameError: name 'different_covid_exams' is not defined

# %%
fleury
# Out:
#                               ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 2        7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 3        7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 4        7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# ...                                   ...         ...       ...
# 2496586  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496587  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496588  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496589  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496590  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
#
#                                                   DE_EXAME  \
# 0        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 2                                  HEMOGRAMA, sangue total
# 3                                  HEMOGRAMA, sangue total
# 4                                  HEMOGRAMA, sangue total
# ...                                                    ...
# 2496586    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496587    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496588    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496589                                    FERRITINA, soro
# 2496590                        25 HIDROXI-VITAMINA D, soro
#
#                                   DE_ANALITO            DE_RESULTADO  \
# 0                 Covid 19, Detecção por PCR           NÃO DETECTADO
# 1                         Covid 19, Material  raspado de nasofaringe
# 2                                Hemoglobina                  Number
# 3                                        VCM                  Number
# 4                                 Leucócitos                  Number
# ...                                      ...                     ...
# 2496586  FAN - Placa Cromossômica Metafásica            Não reagente
# 2496587                 FAN - Citoplasmático            Não reagente
# 2496588              FAN - Aparelho Mitótico            Não reagente
# 2496589                            Ferritina                  Number
# 2496590              25 Hidroxi - vitamina D                  Number
#
#         CD_UNIDADE DE_VALOR_REFERENCIA
# 0              NaN       Não detectado
# 1              NaN                 NaN
# 2             g/dL         13,5 a 17,5
# 3               fL         81,0 a 95,0
# 4             /mm3      3.500 a 10.500
# ...            ...                 ...
# 2496586        NaN        Não reagente
# 2496587        NaN        Não reagente
# 2496588        NaN        Não reagente
# 2496589   microg/L            15 a 149
# 2496590      ng/mL                 NaN
#
# [2496591 rows x 8 columns]

# %% [markdown]
# ## Pivot Table

# %%
pivot = fleury.pivot_table(index=['ID_PACIENTE', 'DT_COLETA'], columns='DE_EXAME', values='DE_RESULTADO', aggfunc=np.max)
pivot

# %%
pivot.to_csv('pivot_caching.csv', index=False)

# %% [markdown]
# ## Grouping by instances

# %% [markdown]
# When we group by intances, we're getting a distribuition of how many instances did a given exam.

# %%
values = fleury['DE_EXAME'].value_counts()
values
# Out:
# HEMOGRAMA, sangue total                                 785838
# URINA TIPO I - JATO MEDIO                               206216
# COVID19, ANTICORPOS IgG, soro                           175728
# COVID19, ANTICORPOS IgM, soro                           168763
# NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR    100518
#                                                          ...
# IGE ESPECIFICO, G2 - GRAMA RASTEIRA, soro                    1
# ANTICORPOS ANTI-ANTIGENO PRECOCE DO VIRUS EB, soro           1
# VÍRUS DA FEBRE AMARELA, DETECÇÃO DO RNA POR PCR              1
# MUSCULO ESTRIADO, AUTO-ANTICORPOS, soro                      1
# IGE ESPECIFICO, F82 - QUEIJO CAMEMBERT, soro                 1
# Name: DE_EXAME, Length: 722, dtype: int64

# %% [markdown]
# Each patient appears with the same exams many times...

# %%
fleury['ID_PACIENTE'].value_counts()

# %% [markdown]
# ## Grouping by patient and exam type

# %% [markdown]
# We'll normalize our dataset in such a way that the tuple (ID_PACIENTE, DE_EXAME) becomes a single instance, in order to find out the most representative exams in terms of the distribuition of patients.

# %%
id_paciente_de_exame = fleury.groupby(['ID_PACIENTE', 'DE_EXAME', 'DE_ANALITO'], as_index=False).agg({'count':'sum'})

# %% [markdown]
# <span style='color:red'>**Strange:**</span> Did someone _really_ do 660 hemograms?

# %%
id_paciente_de_exame.sort_values(['count'], ascending=False)
# Out:
#                               ID_PACIENTE  \
# 1915821  F0C7FF52C472F0815251B16B47553AAB
# 1915822  F0C7FF52C472F0815251B16B47553AAB
# 1586627  C73948E212801903FD62A8335D69BBBA
# 1586620  C73948E212801903FD62A8335D69BBBA
# 627047   4EC221F2B48FFD9ADF0FAB7AD365ACF7
# ...                                   ...
# 736752   5CBC87A43C145857277A63F49C6DC91F
# 736751   5CBC87A43C145857277A63F49C6DC91F
# 736750   5CBC87A43C145857277A63F49C6DC91F
# 736749   5CBC87A43C145857277A63F49C6DC91F
# 2035080  FFFFF4B47815FF61F542AF7D3351A200
#
#                                                   DE_EXAME  \
# 1915821                       TEMPO DE PROTROMBINA, plasma
# 1915822                       TEMPO DE PROTROMBINA, plasma
# 1586627                                        SODIO, soro
# 1586620                                     POTASSIO, soro
# 627047                           URINA TIPO I - JATO MEDIO
# ...                                                    ...
# 736752                       COVID19, ANTICORPOS IgM, soro
# 736751                       COVID19, ANTICORPOS IgM, soro
# 736750                       COVID19, ANTICORPOS IgG, soro
# 736749                       COVID19, ANTICORPOS IgG, soro
# 2035080  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
#
#                                             DE_ANALITO  count
# 1915821                                         TP/INR     39
# 1915822                           Tempo de Protrombina     39
# 1586627                                          Sódio     31
# 1586620                                       Potássio     31
# 627047                        Proteínas, urina isolada     29
# ...                                                ...    ...
# 736752   Covid 19, Anticorpos IgM, Quimioluminescência      1
# 736751   Covid 19, Anticorpos IgM, Quimiolumin.-Índice      1
# 736750   Covid 19, Anticorpos IgG, Quimioluminescência      1
# 736749   Covid 19, Anticorpos IgG, Quimiolumin.-Índice      1
# 2035080                             Covid 19, Material      1
#
# [2035081 rows x 4 columns]

# %%
id_paciente_de_exame['count_exames_e_analitos'] = id_paciente_de_exame['DE_EXAME'] + " - " + id_paciente_de_exame['DE_ANALITO']
exam_per_patient_distribuition = id_paciente_de_exame['count_exames_e_analitos'].value_counts() / id_paciente_de_exame['ID_PACIENTE'].nunique()

# %%
exam_per_patient_distribuition
# Out:
# COVID19, ANTICORPOS IgG, soroCovid 19, Anticorpos IgG, Quimiolumin.-Índice        0.642178
# COVID19, ANTICORPOS IgM, soroCovid 19, Anticorpos IgM, Quimiolumin.-Índice        0.642070
# COVID19, ANTICORPOS IgG, soroCovid 19, Anticorpos IgG, Quimioluminescência        0.633474
# COVID19, ANTICORPOS IgM, soroCovid 19, Anticorpos IgM, Quimioluminescência        0.633350
# NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCRCovid 19, Detecção por PCR    0.371272
#                                                                                     ...
# PESQUISA DE MICROSPORIDIA NAS FEZESMicrosporidia, pesquisa, fezes                 0.000008
# CISTICERCOSE, ANTICORPOS, soroCisticercose, IgG                                   0.000008
# URINA TIPO I - JATO FINALAspecto, urina                                           0.000008
# VÍRUS DA FEBRE AMARELA, DETECÇÃO DO RNA POR PCRFebre Amarela, PCR                 0.000008
# PAINEL SOROLOGICO PARA ENTEROVIRUSVirus Coxsackie - A9                            0.000008
# Name: count_exames_e_analitos, Length: 1279, dtype: float64

# %% [markdown]
# ## Distribuition of the most important exams...

# %%
# %%time
grouped = id_paciente_de_exame.groupby('ID_PACIENTE')
representative_exams_list = exam_per_patient_distribuition.index[:25].to_list()
df = pd.DataFrame(columns=["ID_PACIENTE", *representative_exams_list])

instances = []

for id_paciente, group in grouped:
    aux = {'ID_PACIENTE':id_paciente}
    
    set1 = set(representative_exams_list)
    set2 = set(group['count_exames_e_analitos'])
    
    intersection = set1.intersection(set2)
    
    aux.update({i : True for i in intersection})
    
    instances.append(aux)
        
df = df.append(instances)
df.fillna(False, inplace=True)

# %%
df

# %%
df['COUNT_EXAMS'] = df[representative_exams_list].sum(axis=1)

# %%
df['COUNT_EXAMS'].value_counts()

df.plot(kind='hist', by=['COUNT_EXAMS'], bins=len(representative_exams_list));

# %% [markdown]
# ## Clustering exams

# %%
fleury.groupby(['DE_EXAME']).agg({'count':'sum'})
# Out:
#                                    count
# DE_EXAME
# 1,25-DIHIDROXIVITAMINA D, soro       202
# 11-DESOXICORTICOSTERONA, SORO          1
# 11-DESOXICORTISOL, soro               21
# 17-ALFA-HIDROXIPROGESTERONA, soro    774
# 17-HIDROXI PREGNENOLONA, soro          5
# ...                                  ...
# ZINCO, plasma                       3218
# ZINCO, urina                           1
# pH, Determinação nas fezes            43
# pH, Urina                              6
# ÁCIDO LÁCTICO, plasma                 64
#
# [722 rows x 1 columns]

# %% [markdown]
# ### Dropping 'Number' Results
# A large amount of exams has inconclusive strings as a result, such as "Number" and maintaining these results in the DataFrame will compromise our clusterization, so we will drop them!

# %%
df = fleury[fleury.DE_RESULTADO != "Number"]
df
# Out:
#                               ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 21       7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 22       7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 43       7B10786D64F27D7732503D915A38DE6F  20/03/2020       LAB
# ...                                   ...         ...       ...
# 2496584  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496585  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496586  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496587  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496588  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
#
#                                                   DE_EXAME  \
# 0        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 21                                 HEMOGRAMA, sangue total
# 22                                 HEMOGRAMA, sangue total
# 43       DETECÇÃO DE VÍRUS E BACTÉRIAS DO TRATO RESPIRA...
# ...                                                    ...
# 2496584    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496585    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496586    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496587    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496588    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
#
#                                        DE_ANALITO  \
# 0                      Covid 19, Detecção por PCR
# 1                              Covid 19, Material
# 21                     Morfologia, Série Vermelha
# 22                       Morfologia, Série Branca
# 43       Vírus Respiratórios - Detecção molecular
# ...                                           ...
# 2496584                             FAN - Nuclear
# 2496585                           FAN - Nucleolar
# 2496586       FAN - Placa Cromossômica Metafásica
# 2496587                      FAN - Citoplasmático
# 2496588                   FAN - Aparelho Mitótico
#
#                                               DE_RESULTADO CD_UNIDADE  \
# 0                                            NÃO DETECTADO        NaN
# 1                                   raspado de nasofaringe        NaN
# 21                                                 normais        NaN
# 22       não foram observados caracteres tóxico-degener...        NaN
# 43                                                POSITIVO        NaN
# ...                                                    ...        ...
# 2496584                                       Não reagente        NaN
# 2496585                                       Não reagente        NaN
# 2496586                                       Não reagente        NaN
# 2496587                                       Não reagente        NaN
# 2496588                                       Não reagente        NaN
#
#         DE_VALOR_REFERENCIA  count
# 0             Não detectado      1
# 1                       NaN      1
# 21                      NaN      1
# 22                      NaN      1
# 43                 Negativo      1
# ...                     ...    ...
# 2496584        Não reagente      1
# 2496585        Não reagente      1
# 2496586        Não reagente      1
# 2496587        Não reagente      1
# 2496588        Não reagente      1
#
# [536793 rows x 9 columns]

# %%
# Getting all a list with the names of all the exams.
all_exams = df['DE_EXAME'].unique()

# %%
# Pairing exames with at least 80% if name similarity according to Levenstein's Distance
pairing_percentage = [ (i, j) for j in all_exams for i in all_exams if fuzz.ratio(i, j) > 80 and i != j]
pairing_percentage
# Out:
# [('COVID19, ANTICORPOS IgM, soro', 'COVID19, ANTICORPOS IgG, soro'),
#  ('COVID19, ANTICORPOS IgA, soro', 'COVID19, ANTICORPOS IgG, soro'),
#  ('SARS-COV-2, ANTICORPOS IgG, soro', 'COVID19, ANTICORPOS IgG, soro'),
#  ('COVID19, ANTICORPOS IgG, soro', 'COVID19, ANTICORPOS IgM, soro'),
#  ('COVID19, ANTICORPOS IgA, soro', 'COVID19, ANTICORPOS IgM, soro'),
#  ('DENGUE, ANTICORPOS IgM, soro', 'COVID19, ANTICORPOS IgM, soro'),
#  ('PROTEINA C-REATIVA, soro', 'PROTEINA C-REATIVA, plasma'),
#  ('COVID19, ANTICORPOS IgG, soro', 'COVID19, ANTICORPOS IgA, soro'),
#  ('COVID19, ANTICORPOS IgM, soro', 'COVID19, ANTICORPOS IgA, soro'),
#  ('RUBEOLA, ANTICORPOS IgM, soro', 'CAXUMBA, ANTICORPOS IgM, soro'),
#  ('SARAMPO, ANTICORPOS IgM, soro', 'CAXUMBA, ANTICORPOS IgM, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgM, soro', 'CAXUMBA, ANTICORPOS IgM, soro'),
#  ('CAXUMBA, ANTICORPOS IgG, soro', 'CAXUMBA, ANTICORPOS IgM, soro'),
#  ('TOXOCARA, ANTICORPOS IgG, soro', 'CAXUMBA, ANTICORPOS IgM, soro'),
#  ('RUBEOLA, ANTICORPOS IgG, soro', 'CAXUMBA, ANTICORPOS IgM, soro'),
#  ('DENGUE, ANTICORPOS IgM, soro', 'CAXUMBA, ANTICORPOS IgM, soro'),
#  ('CAXUMBA, ANTICORPOS IgM, soro', 'RUBEOLA, ANTICORPOS IgM, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgM, soro', 'RUBEOLA, ANTICORPOS IgM, soro'),
#  ('CAXUMBA, ANTICORPOS IgG, soro', 'RUBEOLA, ANTICORPOS IgM, soro'),
#  ('RUBEOLA, ANTICORPOS IgG, soro', 'RUBEOLA, ANTICORPOS IgM, soro'),
#  ('DENGUE, ANTICORPOS IgM, soro', 'RUBEOLA, ANTICORPOS IgM, soro'),
#  ('SARAMPO, ANTICORPOS IgM, soro', 'SARAMPO, ANTICORPOS IgG, soro'),
#  ('CAXUMBA, ANTICORPOS IgG, soro', 'SARAMPO, ANTICORPOS IgG, soro'),
#  ('SARS-COV-2, ANTICORPOS IgG, soro', 'SARAMPO, ANTICORPOS IgG, soro'),
#  ('TOXOCARA, ANTICORPOS IgG, soro', 'SARAMPO, ANTICORPOS IgG, soro'),
#  ('RUBEOLA, ANTICORPOS IgG, soro', 'SARAMPO, ANTICORPOS IgG, soro'),
#  ('CAXUMBA, ANTICORPOS IgM, soro', 'SARAMPO, ANTICORPOS IgM, soro'),
#  ('RUBEOLA, ANTICORPOS IgM, soro', 'SARAMPO, ANTICORPOS IgM, soro'),
#  ('SARAMPO, ANTICORPOS IgG, soro', 'SARAMPO, ANTICORPOS IgM, soro'),
#  ('SARS-COV-2, ANTICORPOS IgG, soro', 'SARAMPO, ANTICORPOS IgM, soro'),
#  ('TOXOCARA, ANTICORPOS IgG, soro', 'SARAMPO, ANTICORPOS IgM, soro'),
#  ('VARICELLA-ZOSTER VIRUS, ANTICORPOS IgG, soro',
#   'VARICELLA-ZOSTER VIRUS, ANTICORPOS IgM, soro'),
#  ('CITOMEGALOVIRUS, ANTICORPOS IgM, soro',
#   'CITOMEGALOVIRUS, ANTICORPOS IgG, soro'),
#  ('CENTROMEROS, ANTICORPO IgG, soro', 'CITOMEGALOVIRUS, ANTICORPOS IgG, soro'),
#  ('CITOMEGALOVIRUS, ANTICORPOS IgG, soro',
#   'CITOMEGALOVIRUS, ANTICORPOS IgM, soro'),
#  ('VIRUS EPSTEIN BARR (ANTIGENO DO CAPSIDEO VIRAL), ANTICORPOS IgG, soro',
#   'VIRUS EPSTEIN BARR (ANTIGENO DO CAPSIDEO VIRAL), ANTICORPOS IgM, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgM, soro', 'TOXOPLASMA, ANTICORPOS IgG, soro'),
#  ('CAXUMBA, ANTICORPOS IgG, soro', 'TOXOPLASMA, ANTICORPOS IgG, soro'),
#  ('TOXOCARA, ANTICORPOS IgG, soro', 'TOXOPLASMA, ANTICORPOS IgG, soro'),
#  ('RUBEOLA, ANTICORPOS IgG, soro', 'TOXOPLASMA, ANTICORPOS IgG, soro'),
#  ('LEISHMANIA, ANTICORPOS IgG, soro', 'TOXOPLASMA, ANTICORPOS IgG, soro'),
#  ('HISTOPLASMA, ANTICORPOS TOTAIS, soro', 'TOXOPLASMA, ANTICORPOS IgG, soro'),
#  ('TOXOPLASMA, AVIDEZ DE ANTICORPOS IgG, soro',
#   'TOXOPLASMA, ANTICORPOS IgG, soro'),
#  ('CAXUMBA, ANTICORPOS IgM, soro', 'TOXOPLASMA, ANTICORPOS IgM, soro'),
#  ('RUBEOLA, ANTICORPOS IgM, soro', 'TOXOPLASMA, ANTICORPOS IgM, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgG, soro', 'TOXOPLASMA, ANTICORPOS IgM, soro'),
#  ('TOXOCARA, ANTICORPOS IgG, soro', 'TOXOPLASMA, ANTICORPOS IgM, soro'),
#  ('HISTOPLASMA, ANTICORPOS TOTAIS, soro', 'TOXOPLASMA, ANTICORPOS IgM, soro'),
#  ('TOXOPLASMA, AVIDEZ DE ANTICORPOS IgG, soro',
#   'TOXOPLASMA, ANTICORPOS IgM, soro'),
#  ('ANTICORPOS IgM CONTRA O VIRUS DA HEPATITE A (ANTI-VHA IgM)',
#   'ANTICORPOS TOTAIS CONTRA O VIRUS DA HEPATITE A (Anti-VHA Total)'),
#  ('ANTICORPO CONTRA O ANTIGENO e DO VIRUS DA HEPATITE B (ANTI-HBe), soro',
#   'ANTICORPO CONTRA O ANTIGENO DO CORE DO VIRUS DA HEPATITE B, soro'),
#  ('ANTICORPO IgM CONTRA ANTIGENO DO CORE DO VIRUS DA HEPATITE B, soro',
#   'ANTICORPO CONTRA O ANTIGENO DO CORE DO VIRUS DA HEPATITE B, soro'),
#  ('URINA TIPO I - JATO FINAL', 'URINA TIPO I - JATO MEDIO'),
#  ('GONADOTROFINA CORIONICA HUMANA, soro',
#   'GONADOTROFINA CORIONICA HUMANA (HCG), soro'),
#  ('CAXUMBA, ANTICORPOS IgM, soro', 'CAXUMBA, ANTICORPOS IgG, soro'),
#  ('RUBEOLA, ANTICORPOS IgM, soro', 'CAXUMBA, ANTICORPOS IgG, soro'),
#  ('SARAMPO, ANTICORPOS IgG, soro', 'CAXUMBA, ANTICORPOS IgG, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgG, soro', 'CAXUMBA, ANTICORPOS IgG, soro'),
#  ('TOXOCARA, ANTICORPOS IgG, soro', 'CAXUMBA, ANTICORPOS IgG, soro'),
#  ('RUBEOLA, ANTICORPOS IgG, soro', 'CAXUMBA, ANTICORPOS IgG, soro'),
#  ('HIV-1, ANTICORPOS, soro', 'HTLV1/2, ANTICORPOS, soro'),
#  ('HTLV, ANTICORPOS, soro', 'HTLV1/2, ANTICORPOS, soro'),
#  ('ACIDOS ORGANICOS, urina ', 'ACIDO URICO, urina'),
#  ('HERPES SIMPLEX, TIPO 2, ANTICORPOS IgG, soro',
#   'HERPES SIMPLEX, TIPO 1 e 2, ANTICORPO IgM, soro'),
#  ('HERPES SIMPLEX, TIPO 1, ANTICORPOS IgG, soro',
#   'HERPES SIMPLEX, TIPO 1 e 2, ANTICORPO IgM, soro'),
#  ('HERPES SIMPLEX, TIPO  1 e 2, ANTICORPOS IgG, soro',
#   'HERPES SIMPLEX, TIPO 1 e 2, ANTICORPO IgM, soro'),
#  ('HERPES SIMPLEX, TIPO 1 e 2, ANTICORPO IgM, soro',
#   'HERPES SIMPLEX, TIPO 2, ANTICORPOS IgG, soro'),
#  ('HERPES SIMPLEX, TIPO 1, ANTICORPOS IgG, soro',
#   'HERPES SIMPLEX, TIPO 2, ANTICORPOS IgG, soro'),
#  ('HERPES SIMPLEX, TIPO  1 e 2, ANTICORPOS IgG, soro',
#   'HERPES SIMPLEX, TIPO 2, ANTICORPOS IgG, soro'),
#  ('HTLV1/2, ANTICORPOS, soro', 'HIV-1, ANTICORPOS, soro'),
#  ('HTLV, ANTICORPOS, soro', 'HIV-1, ANTICORPOS, soro'),
#  ('MAG, ANTICORPOS, soro', 'HIV-1, ANTICORPOS, soro'),
#  ('HORMONIO FOLICULO ESTIMULANTE (FSH), soro',
#   'HORMONIO TIROESTIMULANTE (TSH), soro'),
#  ('EXAME PARASITOLOGICO DE FEZES (MIF)', 'EXAME PARASITOLOGICO DE FEZES'),
#  ('COVID19, ANTICORPOS IgG, soro', 'SARS-COV-2, ANTICORPOS IgG, soro'),
#  ('SARAMPO, ANTICORPOS IgG, soro', 'SARS-COV-2, ANTICORPOS IgG, soro'),
#  ('SARAMPO, ANTICORPOS IgM, soro', 'SARS-COV-2, ANTICORPOS IgG, soro'),
#  ('HORMONIO TIROESTIMULANTE (TSH), soro',
#   'HORMONIO FOLICULO ESTIMULANTE (FSH), soro'),
#  ('TESTOSTERONA LIVRE,soro', 'TESTOSTERONA, soro'),
#  ('ANTICORPOS ANTI-HISTONA, soro', 'ANTICORPOS ANTI-MITOCONDRIA, soro'),
#  ('ANTICORPOS ANTI-ADRENAL, soro', 'ANTICORPOS ANTI-MITOCONDRIA, soro'),
#  ('Ro/SS-A, AUTO-ANTICORPOS, soro', 'Scl-70, AUTO-ANTICORPOS, soro'),
#  ('La/SS-B, AUTO-ANTICORPOS, soro', 'Scl-70, AUTO-ANTICORPOS, soro'),
#  ('JO-1, AUTO-ANTICORPOS, soro', 'Scl-70, AUTO-ANTICORPOS, soro'),
#  ('Sm, AUTO-ANTICORPOS, soro', 'Scl-70, AUTO-ANTICORPOS, soro'),
#  ('Sm/RNP, AUTO-ANTICORPOS, soro', 'Scl-70, AUTO-ANTICORPOS, soro'),
#  ('RNP, AUTO-ANTICORPOS, soro', 'Scl-70, AUTO-ANTICORPOS, soro'),
#  ('TRIPANOSSOMA CRUZI, anticorpos Totais, soro',
#   'TRIPANOSSOMA CRUZI, anticorpos IgG, soro'),
#  ('ANTICORPO CONTRA O ANTIGENO DO CORE DO VIRUS DA HEPATITE B, soro',
#   'ANTICORPO CONTRA O ANTIGENO e DO VIRUS DA HEPATITE B (ANTI-HBe), soro'),
#  ('ANTICORPO IgM CONTRA ANTIGENO DO CORE DO VIRUS DA HEPATITE B, soro',
#   'ANTICORPO CONTRA O ANTIGENO e DO VIRUS DA HEPATITE B (ANTI-HBe), soro'),
#  ('GONADOTROFINA CORIONICA HUMANA (HCG), soro',
#   'GONADOTROFINA CORIONICA HUMANA, soro'),
#  ('PROTEINA C-REATIVA, plasma', 'PROTEINA C-REATIVA, soro'),
#  ('PESQUISA TRICOMONAS', 'PESQUISA DE TRICOMONAS'),
#  ('PESQUISA DE TRICOMONAS', 'PESQUISA TRICOMONAS'),
#  ('ENDOMISIO, ANTICORPOS IgG, soro', 'ENDOMISIO, ANTICORPOS IgA, soro'),
#  ('PESQUISA DO PAPILOMAVÍRUS HUMANO (HPV) POR TÉCNICA MOLECULAR',
#   'PESQUISA DO PAPILOMAVÍRUS HUMANO (HPV) DE ALTO RISCO POR TÉCNICA MOLECULAR'),
#  ('DENGUE, ANTICORPOS IgM, PROVA RÁPIDA, soro',
#   'DENGUE, ANTICORPOS IgG, PROVA RÁPIDA, soro'),
#  ('DENGUE, ANTICORPOS IgG, PROVA RÁPIDA, soro',
#   'DENGUE, ANTICORPOS IgM, PROVA RÁPIDA, soro'),
#  ('ANTICORPOS TOTAIS CONTRA O VIRUS DA HEPATITE A (Anti-VHA Total)',
#   'ANTICORPOS IgM CONTRA O VIRUS DA HEPATITE A (ANTI-VHA IgM)'),
#  ('ANTICORPO CONTRA O ANTIGENO DO CORE DO VIRUS DA HEPATITE B, soro',
#   'ANTICORPO IgM CONTRA ANTIGENO DO CORE DO VIRUS DA HEPATITE B, soro'),
#  ('ANTICORPO CONTRA O ANTIGENO e DO VIRUS DA HEPATITE B (ANTI-HBe), soro',
#   'ANTICORPO IgM CONTRA ANTIGENO DO CORE DO VIRUS DA HEPATITE B, soro'),
#  ('PESQUISA DO PAPILOMAVÍRUS HUMANO (HPV) DE ALTO RISCO POR TÉCNICA MOLECULAR',
#   'PESQUISA DO PAPILOMAVÍRUS HUMANO (HPV) POR TÉCNICA MOLECULAR'),
#  ('ZIKA VÍRUS, PESQUISA DE ANTICORPOS DA CLASSE IGG, soro',
#   'ZIKA VÍRUS, PESQUISA DE ANTICORPOS DA CLASSE IGM, soro'),
#  ('ZIKA VÍRUS, PESQUISA DE ANTICORPOS DA CLASSE IGM, soro',
#   'ZIKA VÍRUS, PESQUISA DE ANTICORPOS DA CLASSE IGG, soro'),
#  ('VIRUS EPSTEIN BARR (ANTIGENO DO CAPSIDEO VIRAL), ANTICORPOS IgM, soro',
#   'VIRUS EPSTEIN BARR (ANTIGENO DO CAPSIDEO VIRAL), ANTICORPOS IgG, soro'),
#  ('CHLAMYDIA TRACHOMATIS, ANTICORPOS IgM, soro',
#   'CHLAMYDIA TRACHOMATIS, ANTICORPOS IgG, soro'),
#  ('CHLAMYDIA TRACHOMATIS, ANTICORPOS IgG, soro',
#   'CHLAMYDIA TRACHOMATIS, ANTICORPOS IgM, soro'),
#  ('CAXUMBA, ANTICORPOS IgM, soro', 'TOXOCARA, ANTICORPOS IgG, soro'),
#  ('SARAMPO, ANTICORPOS IgG, soro', 'TOXOCARA, ANTICORPOS IgG, soro'),
#  ('SARAMPO, ANTICORPOS IgM, soro', 'TOXOCARA, ANTICORPOS IgG, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgG, soro', 'TOXOCARA, ANTICORPOS IgG, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgM, soro', 'TOXOCARA, ANTICORPOS IgG, soro'),
#  ('CAXUMBA, ANTICORPOS IgG, soro', 'TOXOCARA, ANTICORPOS IgG, soro'),
#  ('RUBEOLA, ANTICORPOS IgG, soro', 'TOXOCARA, ANTICORPOS IgG, soro'),
#  ('FATOR V LEIDEN E MUTAÇÃO c.20210G>A DO GENE DA PROTROMBINA',
#   'MUTAÇÃO c.20210G>A DO GENE DA PROTROMBINA'),
#  ('MUTAÇÃO c.20210G>A DO GENE DA PROTROMBINA',
#   'FATOR V LEIDEN E MUTAÇÃO c.20210G>A DO GENE DA PROTROMBINA'),
#  ('ELETROFORESE DE PROTEINAS URINARIAS', 'ELETROFORESE DAS PROTEÍNAS SÉRICAS'),
#  ('ENDOMISIO, ANTICORPOS IgA, soro', 'ENDOMISIO, ANTICORPOS IgG, soro'),
#  ('LEISHMANIA, ANTICORPOS IgG, soro', 'ENDOMISIO, ANTICORPOS IgG, soro'),
#  ('CENTROMEROS, ANTICORPO IgG, soro', 'ENDOMISIO, ANTICORPOS IgG, soro'),
#  ('TIROXINA (T4) LIVRE, soro', 'TIROXINA (T4), soro'),
#  ('TESTOSTERONA, soro', 'TESTOSTERONA LIVRE,soro'),
#  ('EXAME PARASITOLOGICO DE FEZES', 'EXAME PARASITOLOGICO DE FEZES (MIF)'),
#  ('Scl-70, AUTO-ANTICORPOS, soro', 'Ro/SS-A, AUTO-ANTICORPOS, soro'),
#  ('La/SS-B, AUTO-ANTICORPOS, soro', 'Ro/SS-A, AUTO-ANTICORPOS, soro'),
#  ('FILAGRINA, AUTO-ANTICORPOS, soro', 'Ro/SS-A, AUTO-ANTICORPOS, soro'),
#  ('JO-1, AUTO-ANTICORPOS, soro', 'Ro/SS-A, AUTO-ANTICORPOS, soro'),
#  ('Sm, AUTO-ANTICORPOS, soro', 'Ro/SS-A, AUTO-ANTICORPOS, soro'),
#  ('Sm/RNP, AUTO-ANTICORPOS, soro', 'Ro/SS-A, AUTO-ANTICORPOS, soro'),
#  ('RNP, AUTO-ANTICORPOS, soro', 'Ro/SS-A, AUTO-ANTICORPOS, soro'),
#  ('Scl-70, AUTO-ANTICORPOS, soro', 'La/SS-B, AUTO-ANTICORPOS, soro'),
#  ('Ro/SS-A, AUTO-ANTICORPOS, soro', 'La/SS-B, AUTO-ANTICORPOS, soro'),
#  ('JO-1, AUTO-ANTICORPOS, soro', 'La/SS-B, AUTO-ANTICORPOS, soro'),
#  ('Sm, AUTO-ANTICORPOS, soro', 'La/SS-B, AUTO-ANTICORPOS, soro'),
#  ('Sm/RNP, AUTO-ANTICORPOS, soro', 'La/SS-B, AUTO-ANTICORPOS, soro'),
#  ('RNP, AUTO-ANTICORPOS, soro', 'La/SS-B, AUTO-ANTICORPOS, soro'),
#  ('IGE ESPECIFICO, F59 - Polvo, soro', 'IGE ESPECIFICO, F49 - MAÇÃ, soro'),
#  ('IGE ESPECIFICO, F49 - MAÇÃ, soro', 'IGE ESPECIFICO, F59 - Polvo, soro'),
#  ('CREATININA, amostra isolada na urina',
#   'PROTEINAS, amostra isolada de urina'),
#  ('CAXUMBA, ANTICORPOS IgM, soro', 'RUBEOLA, ANTICORPOS IgG, soro'),
#  ('RUBEOLA, ANTICORPOS IgM, soro', 'RUBEOLA, ANTICORPOS IgG, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgG, soro', 'RUBEOLA, ANTICORPOS IgG, soro'),
#  ('CAXUMBA, ANTICORPOS IgG, soro', 'RUBEOLA, ANTICORPOS IgG, soro'),
#  ('TOXOCARA, ANTICORPOS IgG, soro', 'RUBEOLA, ANTICORPOS IgG, soro'),
#  ('VÍRUS DA HEPATITE C (HCV), PESQUISA E QUANTIFICAÇÃO DO RNA',
#   'VÍRUS DA HEPATITE B (HBV), PESQUISA E QUANTIFICAÇÃO DO DNA'),
#  ('Ro/SS-A, AUTO-ANTICORPOS, soro', 'FILAGRINA, AUTO-ANTICORPOS, soro'),
#  ('Sm, AUTO-ANTICORPOS, soro', 'FILAGRINA, AUTO-ANTICORPOS, soro'),
#  ('Sm/RNP, AUTO-ANTICORPOS, soro', 'FILAGRINA, AUTO-ANTICORPOS, soro'),
#  ('PROFILAGRINA, AUTO-ANTICORPOS, soro', 'FILAGRINA, AUTO-ANTICORPOS, soro'),
#  ('RNP, AUTO-ANTICORPOS, soro', 'FILAGRINA, AUTO-ANTICORPOS, soro'),
#  ('SARAMPO, ANTICORPOS IgG, soro', 'LEISHMANIA, ANTICORPOS IgG, soro'),
#  ('ENDOMISIO, ANTICORPOS IgG, soro', 'LEISHMANIA, ANTICORPOS IgG, soro'),
#  ('TRIPANOSSOMA CRUZI, anticorpos IgG, soro',
#   'TRIPANOSSOMA CRUZI, anticorpos Totais, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgG, soro', 'HISTOPLASMA, ANTICORPOS TOTAIS, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgM, soro', 'HISTOPLASMA, ANTICORPOS TOTAIS, soro'),
#  ('LISTERIA, ANTICORPOS TOTAIS, soro', 'HISTOPLASMA, ANTICORPOS TOTAIS, soro'),
#  ('Scl-70, AUTO-ANTICORPOS, soro', 'JO-1, AUTO-ANTICORPOS, soro'),
#  ('Ro/SS-A, AUTO-ANTICORPOS, soro', 'JO-1, AUTO-ANTICORPOS, soro'),
#  ('La/SS-B, AUTO-ANTICORPOS, soro', 'JO-1, AUTO-ANTICORPOS, soro'),
#  ('Sm, AUTO-ANTICORPOS, soro', 'JO-1, AUTO-ANTICORPOS, soro'),
#  ('Sm/RNP, AUTO-ANTICORPOS, soro', 'JO-1, AUTO-ANTICORPOS, soro'),
#  ('RNP, AUTO-ANTICORPOS, soro', 'JO-1, AUTO-ANTICORPOS, soro'),
#  ('CISTICERCOSE, ANTICORPOS, soro', 'BRUCELOSE, ANTICORPOS, soro'),
#  ('Scl-70, AUTO-ANTICORPOS, soro', 'Sm, AUTO-ANTICORPOS, soro'),
#  ('Ro/SS-A, AUTO-ANTICORPOS, soro', 'Sm, AUTO-ANTICORPOS, soro'),
#  ('La/SS-B, AUTO-ANTICORPOS, soro', 'Sm, AUTO-ANTICORPOS, soro'),
#  ('FILAGRINA, AUTO-ANTICORPOS, soro', 'Sm, AUTO-ANTICORPOS, soro'),
#  ('JO-1, AUTO-ANTICORPOS, soro', 'Sm, AUTO-ANTICORPOS, soro'),
#  ('Sm/RNP, AUTO-ANTICORPOS, soro', 'Sm, AUTO-ANTICORPOS, soro'),
#  ('RNP, AUTO-ANTICORPOS, soro', 'Sm, AUTO-ANTICORPOS, soro'),
#  ('HISTOPLASMA, ANTICORPOS TOTAIS, soro', 'LISTERIA, ANTICORPOS TOTAIS, soro'),
#  ('Scl-70, AUTO-ANTICORPOS, soro', 'Sm/RNP, AUTO-ANTICORPOS, soro'),
#  ('Ro/SS-A, AUTO-ANTICORPOS, soro', 'Sm/RNP, AUTO-ANTICORPOS, soro'),
#  ('La/SS-B, AUTO-ANTICORPOS, soro', 'Sm/RNP, AUTO-ANTICORPOS, soro'),
#  ('FILAGRINA, AUTO-ANTICORPOS, soro', 'Sm/RNP, AUTO-ANTICORPOS, soro'),
#  ('JO-1, AUTO-ANTICORPOS, soro', 'Sm/RNP, AUTO-ANTICORPOS, soro'),
#  ('Sm, AUTO-ANTICORPOS, soro', 'Sm/RNP, AUTO-ANTICORPOS, soro'),
#  ('RNP, AUTO-ANTICORPOS, soro', 'Sm/RNP, AUTO-ANTICORPOS, soro'),
#  ('HERPES SIMPLEX, TIPO 1 e 2, ANTICORPO IgM, soro',
#   'HERPES SIMPLEX, TIPO 1, ANTICORPOS IgG, soro'),
#  ('HERPES SIMPLEX, TIPO 2, ANTICORPOS IgG, soro',
#   'HERPES SIMPLEX, TIPO 1, ANTICORPOS IgG, soro'),
#  ('HERPES SIMPLEX, TIPO  1 e 2, ANTICORPOS IgG, soro',
#   'HERPES SIMPLEX, TIPO 1, ANTICORPOS IgG, soro'),
#  ('PAINEL PARA ANTICORPOS ANTI-PLAQUETAS, soro',
#   'PAINEL PARA ANTICORPOS ANTI-GANGLIOSÍDEOS, soro'),
#  ('QUANTIFICACAO DE INIBIDOR DE FATOR IX, plasma',
#   'QUANTIFICACAO DE INIBIDOR DE FATOR VIII, plasma'),
#  ('QUANTIFICACAO DE INIBIDOR DE FATOR VIII, plasma',
#   'QUANTIFICACAO DE INIBIDOR DE FATOR IX, plasma'),
#  ('VÍRUS DA HEPATITE B (HBV), PESQUISA E QUANTIFICAÇÃO DO DNA',
#   'VÍRUS DA HEPATITE C (HCV), PESQUISA E QUANTIFICAÇÃO DO RNA'),
#  ('TIROXINA (T4), soro', 'TIROXINA (T4) LIVRE, soro'),
#  ('FILAGRINA, AUTO-ANTICORPOS, soro', 'PROFILAGRINA, AUTO-ANTICORPOS, soro'),
#  ('RNP, AUTO-ANTICORPOS, soro', 'PROFILAGRINA, AUTO-ANTICORPOS, soro'),
#  ('HTLV1/2, ANTICORPOS, soro', 'HTLV, ANTICORPOS, soro'),
#  ('HIV-1, ANTICORPOS, soro', 'HTLV, ANTICORPOS, soro'),
#  ('MAG, ANTICORPOS, soro', 'HTLV, ANTICORPOS, soro'),
#  ('HERPES SIMPLEX, TIPO 1 e 2, ANTICORPO IgM, soro',
#   'HERPES SIMPLEX, TIPO  1 e 2, ANTICORPOS IgG, soro'),
#  ('HERPES SIMPLEX, TIPO 2, ANTICORPOS IgG, soro',
#   'HERPES SIMPLEX, TIPO  1 e 2, ANTICORPOS IgG, soro'),
#  ('HERPES SIMPLEX, TIPO 1, ANTICORPOS IgG, soro',
#   'HERPES SIMPLEX, TIPO  1 e 2, ANTICORPOS IgG, soro'),
#  ('ANTICORPOS ANTI-ADRENAL, soro', 'ANTICORPOS ANTIAQUAPORINA 4, soro'),
#  ('URINA TIPO I - JATO MEDIO', 'URINA TIPO I - JATO FINAL'),
#  ('ANTICORPOS ANTI-MITOCONDRIA, soro', 'ANTICORPOS ANTI-HISTONA, soro'),
#  ('ANTICORPOS ANTI-ADRENAL, soro', 'ANTICORPOS ANTI-HISTONA, soro'),
#  ('ANTICORPOS ANTI-GAD, soro', 'ANTICORPOS ANTI-HISTONA, soro'),
#  ('CITOMEGALOVIRUS, ANTICORPOS IgG, soro', 'CENTROMEROS, ANTICORPO IgG, soro'),
#  ('ENDOMISIO, ANTICORPOS IgG, soro', 'CENTROMEROS, ANTICORPO IgG, soro'),
#  ('BRUCELOSE, ANTICORPOS, soro', 'CISTICERCOSE, ANTICORPOS, soro'),
#  ('ELETROFORESE DAS PROTEÍNAS SÉRICAS', 'ELETROFORESE DE PROTEINAS URINARIAS'),
#  ('PAINEL PARA ANTICORPOS ANTI-GANGLIOSÍDEOS, soro',
#   'PAINEL PARA ANTICORPOS ANTI-PLAQUETAS, soro'),
#  ('MYCOPLASMA PNEUMONIAE, ANTICORPOS IgG e IgM, soro',
#   'CHLAMYDOPHILA PNEUMONIAE, ANTICORPOS IgM, soro'),
#  ('PROTEINAS, amostra isolada de urina',
#   'CREATININA, amostra isolada na urina'),
#  ('MAG, ANTICORPOS, soro', 'CANDIDA, ANTICORPOS, soro'),
#  ('ACIDO URICO, urina', 'ACIDOS ORGANICOS, urina '),
#  ('TOXOPLASMA, ANTICORPOS IgG, soro',
#   'TOXOPLASMA, AVIDEZ DE ANTICORPOS IgG, soro'),
#  ('TOXOPLASMA, ANTICORPOS IgM, soro',
#   'TOXOPLASMA, AVIDEZ DE ANTICORPOS IgG, soro'),
#  ('ANTICORPOS ANTI-MITOCONDRIA, soro', 'ANTICORPOS ANTI-ADRENAL, soro'),
#  ('ANTICORPOS ANTIAQUAPORINA 4, soro', 'ANTICORPOS ANTI-ADRENAL, soro'),
#  ('ANTICORPOS ANTI-HISTONA, soro', 'ANTICORPOS ANTI-ADRENAL, soro'),
#  ('ANTICORPOS ANTI-GAD, soro', 'ANTICORPOS ANTI-ADRENAL, soro'),
#  ('Scl-70, AUTO-ANTICORPOS, soro', 'RNP, AUTO-ANTICORPOS, soro'),
#  ('Ro/SS-A, AUTO-ANTICORPOS, soro', 'RNP, AUTO-ANTICORPOS, soro'),
#  ('La/SS-B, AUTO-ANTICORPOS, soro', 'RNP, AUTO-ANTICORPOS, soro'),
#  ('FILAGRINA, AUTO-ANTICORPOS, soro', 'RNP, AUTO-ANTICORPOS, soro'),
#  ('JO-1, AUTO-ANTICORPOS, soro', 'RNP, AUTO-ANTICORPOS, soro'),
#  ('Sm, AUTO-ANTICORPOS, soro', 'RNP, AUTO-ANTICORPOS, soro'),
#  ('Sm/RNP, AUTO-ANTICORPOS, soro', 'RNP, AUTO-ANTICORPOS, soro'),
#  ('VARICELLA-ZOSTER VIRUS, ANTICORPOS IgM, soro',
#   'VARICELLA-ZOSTER VIRUS, ANTICORPOS IgG, soro'),
#  ('COVID19, ANTICORPOS IgM, soro', 'DENGUE, ANTICORPOS IgM, soro'),
#  ('CAXUMBA, ANTICORPOS IgM, soro', 'DENGUE, ANTICORPOS IgM, soro'),
#  ('RUBEOLA, ANTICORPOS IgM, soro', 'DENGUE, ANTICORPOS IgM, soro'),
#  ('RUBEOLA, ANTICORPOS IgG, soro', 'DENGUE, ANTICORPOS IgM, soro'),
#  ('HIV-1, ANTICORPOS, soro', 'MAG, ANTICORPOS, soro'),
#  ('HTLV, ANTICORPOS, soro', 'MAG, ANTICORPOS, soro'),
#  ('CANDIDA, ANTICORPOS, soro', 'MAG, ANTICORPOS, soro'),
#  ('ANTICORPOS ANTI-HISTONA, soro', 'ANTICORPOS ANTI-GAD, soro'),
#  ('ANTICORPOS ANTI-ADRENAL, soro', 'ANTICORPOS ANTI-GAD, soro')]

# %% [markdown]
# ### Preparation for clustering...

# %%
# Adjacencies matrix...
adj_matrix = np.array([ np.array([ fuzz.ratio(i, j) for j in all_exams]) for i in all_exams])

# Linkage clusterization using linkage matrices.
Z = linkage(adj_matrix, method="ward", optimal_ordering=True)

# %% [markdown]
# ## Plotting our results...

# %%
# Plotting our cluster as a dendrogram.
plt.figure(figsize=(50, 20))
dn = dendrogram(Z, labels=all_exams)
plt.show()

# %% [markdown]
# ## Visualizing our adjacency matrix as a heatmap

# %%
heatmap(adj_matrix)
