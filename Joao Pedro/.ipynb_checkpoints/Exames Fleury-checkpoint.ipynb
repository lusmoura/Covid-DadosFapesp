# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# !ls '../Dados/Fleury/'
# Out:
#  fleury.zip
# 'Grupo_Fleury_Dataset_Covid19_Dicionário de Dados.xlsx'
#  Grupo_Fleury_Dataset_Covid19_Pacientes.csv
#  Grupo_Fleury_Dataset_Covid19_Resultados_Exames.csv

# %% [markdown]
# ## Lendo datasets

# %%
fleury = pd.read_csv('../Dados/Fleury/Grupo_Fleury_Dataset_Covid19_Resultados_Exames.csv', sep='|', encoding = "ISO-8859-1")
fleury_pacientes = pd.read_csv('../Dados/Fleury/Grupo_Fleury_Dataset_Covid19_Pacientes.csv', sep='|', encoding = "ISO-8859-1")
fleury = fleury[['ID_PACIENTE', 'DT_COLETA', 'DE_ORIGEM', 'DE_EXAME', 
                       'DE_ANALITO', 'DE_RESULTADO', 'CD_UNIDADE', 'DE_VALOR_REFERENCIA']].copy()

# %% [markdown]
# # EDA

# %%
fleury_pacientes['IC_SEXO'].value_counts() / fleury_pacientes['IC_SEXO'].value_counts().sum() * 100
# Out:
# F    56.650668
# M    43.349332
# Name: IC_SEXO, dtype: float64

# %%
fleury_pacientes['AA_NASCIMENTO'].drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-dbf02a36a09e> in <module>
# ----> 1 fleury_pacientes['AA_NASCIMENTO'].drop()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4130         dtype: float64
#    4131         """
# -> 4132         return super().drop(
#    4133             labels=labels,
#    4134             axis=axis,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3926             axes, _ = self._construct_axes_from_arguments((index, columns), {})
#    3927         else:
# -> 3928             raise ValueError(
#    3929                 "Need to specify at least one of 'labels', 'index' or 'columns'"
#    3930             )
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'

# %% [markdown]
# ## Casos estranhos

# %% [markdown]
# ### Três valores de referência para o mesmo exame com mesmo analito

# %%
fleury[(fleury['DE_ANALITO'] == 'Covid 19, Anticorpos IgG, Quimiolumin.-Índice') &
       (fleury['DE_EXAME'] == 'COVID19, ANTICORPOS IgG, soro')]['DE_VALOR_REFERENCIA'].unique()
# Out:
# array(['inferior a 1,0', 'inferior a 0,8', 'inferior a 0,9', nan],
#       dtype=object)

# %% [markdown]
# ## Processando

# %%
fleury['DE_VALOR_REFERENCIA'] = fleury['DE_VALOR_REFERENCIA'].replace(np.nan, 'NaN')
fleury['CD_UNIDADE'] = fleury['CD_UNIDADE'].replace(np.nan, 'NaN')

# %%
fleury.loc[fleury['DE_VALOR_REFERENCIA'].str.contains('\d+', regex=True), 'DE_RESULTADO'] = 'Number'

# %%
fleury.head()
# Out:
#                         ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1  1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 2  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 3  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 4  7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
#
#                                             DE_EXAME  \
# 0  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1  NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 2                            HEMOGRAMA, sangue total
# 3                            HEMOGRAMA, sangue total
# 4                            HEMOGRAMA, sangue total
#
#                    DE_ANALITO            DE_RESULTADO CD_UNIDADE  \
# 0  Covid 19, Detecção por PCR           NÃO DETECTADO        NaN
# 1          Covid 19, Material  raspado de nasofaringe        NaN
# 2                 Hemoglobina                  Number       g/dL
# 3                         VCM                  Number         fL
# 4                  Leucócitos                  Number       /mm3
#
#   DE_VALOR_REFERENCIA
# 0       Não detectado
# 1                 NaN
# 2         13,5 a 17,5
# 3         81,0 a 95,0
# 4      3.500 a 10.500

# %%
def check_float(string):
    try:
        number = float(string)
        return 'Number'
    except:
        return string

# %%
fleury['DE_RESULTADO'] = fleury['DE_RESULTADO'].str.replace(',', '.')
fleury['DE_RESULTADO'] = fleury['DE_RESULTADO'].apply(lambda x: check_float(x))

# %% [markdown]
# ## Vários exames de COVID-19

# %%
different_covid_exams = fleury[(fleury['DE_EXAME'].str.contains('COV')) | (fleury['DE_EXAME'].str.contains(
    'Corona')) | (fleury['DE_EXAME'].str.contains('CORONAV'))]['DE_EXAME'].unique()

# %%
for exam in different_covid_exams:
    print(exam)
# Out:
# NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR
# COVID19, ANTICORPOS IgG, soro
# COVID19, ANTICORPOS IgM, soro
# COVID19, ANTICORPOS IgA, soro
# SARS-COV-2, ANTICORPOS IgG, soro

# %%
different_covid_exams.size
# Out:
# 5

# %%
fleury['count'] = 1

fleury_cov = fleury[fleury['DE_EXAME'].isin(different_covid_exams)].copy()
fleury_cov = fleury_cov.groupby(
    ['DE_EXAME', 'DE_ANALITO', 'DE_RESULTADO', 'CD_UNIDADE', 'DE_VALOR_REFERENCIA']).agg({'count': 'sum'})

# %%
fleury
# Out:
#                               ID_PACIENTE   DT_COLETA DE_ORIGEM  \
# 0        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 1        1AD07C7A1E4D80B608DD7A650766CCF0  19/03/2020       LAB
# 2        7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 3        7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# 4        7B10786D64F27D7732503D915A38DE6F  30/12/2019       LAB
# ...                                   ...         ...       ...
# 2496586  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496587  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496588  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496589  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
# 2496590  D843FFC0D6067B15F25FDBA6AA07D235  15/06/2020       LAB
#
#                                                   DE_EXAME  \
# 0        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 1        NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO P...
# 2                                  HEMOGRAMA, sangue total
# 3                                  HEMOGRAMA, sangue total
# 4                                  HEMOGRAMA, sangue total
# ...                                                    ...
# 2496586    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496587    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496588    ANTIGENOS INTRACELULARES, AUTO-ANTICORPOS (FAN)
# 2496589                                    FERRITINA, soro
# 2496590                        25 HIDROXI-VITAMINA D, soro
#
#                                   DE_ANALITO            DE_RESULTADO  \
# 0                 Covid 19, Detecção por PCR           NÃO DETECTADO
# 1                         Covid 19, Material  raspado de nasofaringe
# 2                                Hemoglobina                  Number
# 3                                        VCM                  Number
# 4                                 Leucócitos                  Number
# ...                                      ...                     ...
# 2496586  FAN - Placa Cromossômica Metafásica            Não reagente
# 2496587                 FAN - Citoplasmático            Não reagente
# 2496588              FAN - Aparelho Mitótico            Não reagente
# 2496589                            Ferritina                  Number
# 2496590              25 Hidroxi - vitamina D                  Number
#
#         CD_UNIDADE DE_VALOR_REFERENCIA  count
# 0              NaN       Não detectado      1
# 1              NaN                 NaN      1
# 2             g/dL         13,5 a 17,5      1
# 3               fL         81,0 a 95,0      1
# 4             /mm3      3.500 a 10.500      1
# ...            ...                 ...    ...
# 2496586        NaN        Não reagente      1
# 2496587        NaN        Não reagente      1
# 2496588        NaN        Não reagente      1
# 2496589   microg/L            15 a 149      1
# 2496590      ng/mL                 NaN      1
#
# [2496591 rows x 9 columns]

# %% [markdown]
# ## Pivot Table

# %%
pivot = fleury.pivot_table(index=['ID_PACIENTE', 'DT_COLETA'], columns='DE_EXAME', values='DE_RESULTADO', aggfunc=np.max)
pivot
# Out:
# DE_ANALITO                                  11-Desoxicorticosterona  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                     NaN
#                                  15/05/2020                     NaN
#                                  21/01/2020                     NaN
#                                  28/11/2019                     NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                     NaN
# ...                                                             ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                     NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                     NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                     NaN
#                                  09/04/2020                     NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                     NaN
#
# DE_ANALITO                                  11-Desoxicortisol  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020               NaN
#                                  15/05/2020               NaN
#                                  21/01/2020               NaN
#                                  28/11/2019               NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020               NaN
# ...                                                       ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020               NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020               NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020               NaN
#                                  09/04/2020               NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020               NaN
#
# DE_ANALITO                                  17-Alfa-Hidroxiprogesterona  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                         NaN
#                                  15/05/2020                         NaN
#                                  21/01/2020                         NaN
#                                  28/11/2019                         NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                         NaN
# ...                                                                 ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                         NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                         NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                         NaN
#                                  09/04/2020                         NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                         NaN
#
# DE_ANALITO                                  17-Hidroxi Pregnenolona  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                     NaN
#                                  15/05/2020                     NaN
#                                  21/01/2020                     NaN
#                                  28/11/2019                     NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                     NaN
# ...                                                             ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                     NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                     NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                     NaN
#                                  09/04/2020                     NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                     NaN
#
# DE_ANALITO                                  17-alfa-hidroxiprogesterona  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                         NaN
#                                  15/05/2020                         NaN
#                                  21/01/2020                         NaN
#                                  28/11/2019                         NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                         NaN
# ...                                                                 ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                         NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                         NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                         NaN
#                                  09/04/2020                         NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                         NaN
#
# DE_ANALITO                                  25 Hidroxi - vitamina D  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                  Number
#                                  15/05/2020                     NaN
#                                  21/01/2020                  Number
#                                  28/11/2019                  Number
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                  Number
# ...                                                             ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                     NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                     NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                     NaN
#                                  09/04/2020                     NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                     NaN
#
# DE_ANALITO                                  250H - Vitamina D Total  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                     NaN
#                                  15/05/2020                     NaN
#                                  21/01/2020                     NaN
#                                  28/11/2019                     NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                     NaN
# ...                                                             ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                     NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                     NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                     NaN
#                                  09/04/2020                     NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                     NaN
#
# DE_ANALITO                                  25OH-Vitamina D2 25OH-Vitamina D3  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020              NaN              NaN
#                                  15/05/2020              NaN              NaN
#                                  21/01/2020              NaN              NaN
#                                  28/11/2019              NaN              NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020              NaN              NaN
# ...                                                      ...              ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020              NaN              NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020              NaN              NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020              NaN              NaN
#                                  09/04/2020              NaN              NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020              NaN              NaN
#
# DE_ANALITO                                  5 Hidroxi-indolacetico  ...  \
# ID_PACIENTE                      DT_COLETA                          ...
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                    NaN  ...
#                                  15/05/2020                    NaN  ...
#                                  21/01/2020                    NaN  ...
#                                  28/11/2019                    NaN  ...
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                    NaN  ...
# ...                                                            ...  ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                    NaN  ...
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                    NaN  ...
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                    NaN  ...
#                                  09/04/2020                    NaN  ...
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                    NaN  ...
#
# DE_ANALITO                                  Ácido homovanílico, urina - no volume enviado  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                                           NaN
#                                  15/05/2020                                           NaN
#                                  21/01/2020                                           NaN
#                                  28/11/2019                                           NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                                           NaN
# ...                                                                                   ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                                           NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                                           NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                                           NaN
#                                  09/04/2020                                           NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                                           NaN
#
# DE_ANALITO                                  Ácido metilmalonico, soro  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                       NaN
#                                  15/05/2020                       NaN
#                                  21/01/2020                       NaN
#                                  28/11/2019                       NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                       NaN
# ...                                                               ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                       NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                       NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                       NaN
#                                  09/04/2020                       NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                       NaN
#
# DE_ANALITO                                  Ácido Úrico, soro  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020            Number
#                                  15/05/2020               NaN
#                                  21/01/2020               NaN
#                                  28/11/2019            Number
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020            Number
# ...                                                       ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020               NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020               NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020               NaN
#                                  09/04/2020               NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020               NaN
#
# DE_ANALITO                                  Ácido Úrico, urina  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                NaN
#                                  15/05/2020                NaN
#                                  21/01/2020                NaN
#                                  28/11/2019                NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                NaN
# ...                                                        ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                NaN
#                                  09/04/2020                NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                NaN
#
# DE_ANALITO                                  Ácido Úrico, urina isolada  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                        NaN
#                                  15/05/2020                        NaN
#                                  21/01/2020                        NaN
#                                  28/11/2019                        NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                        NaN
# ...                                                                ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                        NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                        NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                        NaN
#                                  09/04/2020                        NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                        NaN
#
# DE_ANALITO                                  Ácidos biliares totais  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                    NaN
#                                  15/05/2020                    NaN
#                                  21/01/2020                    NaN
#                                  28/11/2019                    NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                    NaN
# ...                                                            ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                    NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                    NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                    NaN
#                                  09/04/2020                    NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                    NaN
#
# DE_ANALITO                                  Ácidos graxos e sabões  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                    NaN
#                                  15/05/2020                    NaN
#                                  21/01/2020                    NaN
#                                  28/11/2019                    NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                    NaN
# ...                                                            ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                    NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                    NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                    NaN
#                                  09/04/2020                    NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                    NaN
#
# DE_ANALITO                                  Ácidos organicos, urina  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                     NaN
#                                  15/05/2020                     NaN
#                                  21/01/2020                     NaN
#                                  28/11/2019                     NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                     NaN
# ...                                                             ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                     NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                     NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                     NaN
#                                  09/04/2020                     NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                     NaN
#
# DE_ANALITO                                  Ésteres de Carnitina (EC)  \
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                       NaN
#                                  15/05/2020                       NaN
#                                  21/01/2020                       NaN
#                                  28/11/2019                       NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                       NaN
# ...                                                               ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                       NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                       NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                       NaN
#                                  09/04/2020                       NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                       NaN
#
# DE_ANALITO                                  Índice de Green & King
# ID_PACIENTE                      DT_COLETA
# 00007BB4274722A63A38D415ACCD7705 13/05/2020                    NaN
#                                  15/05/2020                    NaN
#                                  21/01/2020                    NaN
#                                  28/11/2019                    NaN
# 000085C48A31F50AE4F147392F6F35CF 01/06/2020                    NaN
# ...                                                            ...
# FFFEE8D64EC3D42D4544F5DF21F3BAA5 20/05/2020                    NaN
# FFFEF2D4D69B8D55ED11FFB5E0DD661D 13/06/2020                    NaN
# FFFFD7BD5939EF03FA62545752DF57D9 04/06/2020                    NaN
#                                  09/04/2020                    NaN
# FFFFF4B47815FF61F542AF7D3351A200 06/06/2020                    NaN
#
# [183098 rows x 978 columns]

# %%
pivot.to_csv('pivot_caching.csv', index=False)

# %% [markdown]
# ## Grouping by instances

# %% [markdown]
# When we group by intances, we're getting a distribuition of how many instances did a given exam.

# %%
values = fleury['DE_EXAME'].value_counts()
values
# Out:
# HEMOGRAMA, sangue total                                 785838
# URINA TIPO I - JATO MEDIO                               206216
# COVID19, ANTICORPOS IgG, soro                           175728
# COVID19, ANTICORPOS IgM, soro                           168763
# NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR    100518
#                                                          ...
# PESQUISA DE TOXOPLASMA GONDII POR MÉTODO MOLECULAR           1
# RUBEOLA, AVIDEZ DE ANTICORPOS IgG, soro                      1
# ZINCO, urina                                                 1
# ACIDO LACTICO, plasma (amostra arterial)                     1
# IgE ESPECÍFICO, rHev B8 LÁTEX, soro                          1
# Name: DE_EXAME, Length: 722, dtype: int64

# %% [markdown]
# Each patient appears with the same exams many times...

# %%
fleury['ID_PACIENTE'].value_counts()
# Out:
# FD10C24CA5986B00FFDDED743447EC81    908
# CE1F4D06FE83023E08DF680EC7324BF5    756
# D1FF1DC925E1126296C7A210AD234E14    745
# C871E03A1744DBBB71A116A1DF657373    707
# A9DEF7F65875D4B92E59D50F9B21DCF2    697
#                                    ...
# 3E2BEBB4C1320DB9BDE20BCD9F332A3F      2
# 9FF3F587DDF05C3C5F20CDF581211772      2
# 7F09162B735D691BCAEC1755B34A5D62      2
# 273CD446E6C929501C12F95842B4398F      1
# C0C91D37570E97ACD7A59A3E9ECA1DAD      1
# Name: ID_PACIENTE, Length: 129595, dtype: int64

# %% [markdown]
# ## Grouping by patient and exam type

# %% [markdown]
# We'll normalize our dataset in such a way that the tuple (ID_PACIENTE, DE_EXAME) becomes a single instance, in order to find out the most representative exams in terms of the distribuition of patients.

# %%
id_paciente_de_exame = fleury.groupby(['ID_PACIENTE', 'DE_EXAME'], as_index=False).agg({'count':'sum'})

# %% [markdown]
# <span style='color:red'>**Strange:**</span> Did someone _really_ do 660 hemograms?

# %%
id_paciente_de_exame.sort_values(['count'], ascending=False)
# Out:
#                              ID_PACIENTE  \
# 986929  FD10C24CA5986B00FFDDED743447EC81
# 984506  FC5675885071BBF89EE97CFFBB80B5D8
# 978242  FAA5901EFED27DA59E52593A315F28C3
# 163485  2A48A97C9B3F9890B9161E398033E52B
# 331778  5534A67A9A354C52E29D5F36F7A9FFF5
# ...                                  ...
# 575718  9359C5C99CE7AC72F287E5B84FBB2D6F
# 575719  9359C5C99CE7AC72F287E5B84FBB2D6F
# 575720  9359C5C99CE7AC72F287E5B84FBB2D6F
# 575721  9359C5C99CE7AC72F287E5B84FBB2D6F
# 104198  1AE9290A011B2BBE44B8B551B58A89EC
#
#                                                  DE_EXAME  count
# 986929                            HEMOGRAMA, sangue total    660
# 984506                            HEMOGRAMA, sangue total    440
# 978242                            HEMOGRAMA, sangue total    430
# 163485                            HEMOGRAMA, sangue total    428
# 331778                            HEMOGRAMA, sangue total    416
# ...                                                   ...    ...
# 575718                     FOSFATASE ALCALINA (ALP), soro      1
# 575719          GAMA GLUTAMIL TRANSFERASE (GAMA-GT), soro      1
# 575720                                    GLICOSE, plasma      1
# 575721  GLOBULINA LIGADORA DE HORMONIOS SEXUAIS(SHBG),...      1
# 104198                                  ACIDO URICO, soro      1
#
# [998778 rows x 3 columns]

# %%
exam_per_patient_distribuition = id_paciente_de_exame['DE_EXAME'].value_counts() / id_paciente_de_exame['ID_PACIENTE'].nunique()

# %%
exam_per_patient_distribuition[exam_per_patient_distribuition > 0.1]
# Out:
# COVID19, ANTICORPOS IgG, soro                           0.665944
# COVID19, ANTICORPOS IgM, soro                           0.642070
# NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR    0.371272
# HEMOGRAMA, sangue total                                 0.193102
# CREATININA, soro                                        0.158293
# TRIGLICERIDES, soro                                     0.153432
# HORMONIO TIROESTIMULANTE (TSH), soro                    0.153293
# COLESTEROL TOTAL, soro                                  0.153100
# HDL-COLESTEROL, soro                                    0.152305
# TRANSAMINASE GLUTAMICO-PIRUVICA (TGP)                   0.149959
# LDL-COLESTEROL, soro                                    0.149010
# TRANSAMINASE GLUTAMICO-OXALACETICA (TGO)                0.148864
# NÃO-HDL-COLESTEROL, soro                                0.148787
# VLDL-COLESTEROL, soro                                   0.144273
# UREIA, soro                                             0.140777
# TIROXINA (T4) LIVRE, soro                               0.132497
# GLICOSE, plasma                                         0.130885
# HEMOGLOBINA GLICADA (A1C), sangue total                 0.125151
# 25 HIDROXI-VITAMINA D, soro                             0.121046
# GAMA GLUTAMIL TRANSFERASE (GAMA-GT), soro               0.114449
# FERRITINA, soro                                         0.101755
# Name: DE_EXAME, dtype: float64

# %%
id_paciente_de_exame[(id_paciente_de_exame['DE_EXAME'] == 'COVID19, ANTICORPOS IgG, soro') |
                    (id_paciente_de_exame['DE_EXAME'] == 'COVID19, ANTICORPOS IgM, soro')]
# Out:
#                              ID_PACIENTE                       DE_EXAME  count
# 11      00007BB4274722A63A38D415ACCD7705  COVID19, ANTICORPOS IgG, soro      2
# 12      00007BB4274722A63A38D415ACCD7705  COVID19, ANTICORPOS IgM, soro      2
# 101     0000A150D4C8B92A4F8D280C6D4656B0  COVID19, ANTICORPOS IgG, soro      2
# 102     0000A150D4C8B92A4F8D280C6D4656B0  COVID19, ANTICORPOS IgM, soro      2
# 103     000230CE71238C85771268A5B7D807BC  COVID19, ANTICORPOS IgG, soro      2
# ...                                  ...                            ...    ...
# 998770  FFFEDE2AD60338139A0CEB7019D1B687  COVID19, ANTICORPOS IgM, soro      2
# 998772  FFFEF2D4D69B8D55ED11FFB5E0DD661D  COVID19, ANTICORPOS IgG, soro      2
# 998773  FFFEF2D4D69B8D55ED11FFB5E0DD661D  COVID19, ANTICORPOS IgM, soro      2
# 998774  FFFFD7BD5939EF03FA62545752DF57D9  COVID19, ANTICORPOS IgG, soro      2
# 998775  FFFFD7BD5939EF03FA62545752DF57D9  COVID19, ANTICORPOS IgM, soro      2
#
# [169512 rows x 3 columns]

# %%
grouped = id_paciente_de_exame.groupby('ID_PACIENTE')
representative_exams_list = exam_per_patient_distribuition.index[:9].to_list()
df = pd.DataFrame(columns=["ID_PACIENTE", *representative_exams_list])

# %%
instances = []
max_iter = 0
for id_paciente, group in grouped:
    if (max_iter > 10):
        break
    aux = dict.fromkeys(representative_exams_list, False)
    aux = {'ID_PACIENTE':id_paciente}
    
    set1 = set(representative_exams_list)
    set2 = set(group['DE_EXAME'])
    
    intersection = set1.intersection(set2)
        
    aux = aux.update({i: True for i in intersection})
    print(aux)
    
    instances.append(aux)
    
    max_iter += 1
    
# df.append(instances)
# Out:
# {'ID_PACIENTE': '00007BB4274722A63A38D415ACCD7705', 'TRIGLICERIDES, soro': True, 'COVID19, ANTICORPOS IgM, soro': True, 'COVID19, ANTICORPOS IgG, soro': True, 'HORMONIO TIROESTIMULANTE (TSH), soro': True, 'COLESTEROL TOTAL, soro': True, 'CREATININA, soro': True, 'HDL-COLESTEROL, soro': True, 'HEMOGRAMA, sangue total': True}
# {'ID_PACIENTE': '000085C48A31F50AE4F147392F6F35CF', 'NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR': True, 'TRIGLICERIDES, soro': True, 'HORMONIO TIROESTIMULANTE (TSH), soro': True, 'COLESTEROL TOTAL, soro': True, 'CREATININA, soro': True, 'HDL-COLESTEROL, soro': True, 'HEMOGRAMA, sangue total': True}
# {'ID_PACIENTE': '0000A150D4C8B92A4F8D280C6D4656B0', 'COVID19, ANTICORPOS IgG, soro': True, 'COVID19, ANTICORPOS IgM, soro': True}
# {'ID_PACIENTE': '000230CE71238C85771268A5B7D807BC', 'COVID19, ANTICORPOS IgG, soro': True, 'COVID19, ANTICORPOS IgM, soro': True}
# {'ID_PACIENTE': '0002632EFE862D6479C37F4E21AE33AB'}
# {'ID_PACIENTE': '00026AF3CD39CC9D4CB97A70B0CBEEBF', 'COVID19, ANTICORPOS IgG, soro': True, 'COVID19, ANTICORPOS IgM, soro': True}
# {'ID_PACIENTE': '00029A8E0091126C7A0D22568D37C5AA', 'NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR': True, 'HEMOGRAMA, sangue total': True, 'HORMONIO TIROESTIMULANTE (TSH), soro': True}
# {'ID_PACIENTE': '000361AFC8886D4D822B30F6F5BE75EF', 'COVID19, ANTICORPOS IgG, soro': True, 'COVID19, ANTICORPOS IgM, soro': True}
# {'ID_PACIENTE': '0003BC5E60FA904CFB57A202BD8748E8', 'NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR': True}
# {'ID_PACIENTE': '0003EA8AB206859133E95FA71D2AF4C5', 'NOVO CORONAVÍRUS 2019 (SARS-CoV-2), DETECÇÃO POR PCR': True}
# {'ID_PACIENTE': '0004F560A11F59C884517103EAEF695B', 'COVID19, ANTICORPOS IgG, soro': True, 'COVID19, ANTICORPOS IgM, soro': True}

# %%
a = {}
